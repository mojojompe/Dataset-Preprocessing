# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sb
print("Imported")
# Out:
# Imported

# %%
dataset = pd.read_csv('ourdataset.csv')
print("Read")
# Out:
# Read

# %%
dataset.head()
# Out:
#            unix        date    symbol    open    high     low   close  \
# 0  1.640000e+12  12-27-2021       NaN  0.9200  0.9237  0.9200  0.9226
# 1  1.640000e+12  12-26-2021  XRP-USDT  0.9252  0.9334  0.9052  0.9200
# 2  1.640000e+12  12-25-2021  XRP-USDT  0.9114  0.9350  0.8981  0.9252
# 3  1.640000e+12  12-24-2021       NaN  0.9941  0.9966  0.8964  0.9115
# 4  1.640000e+12  12-23-2021  XRP-USDT  0.9538  1.0167  0.9372  0.9941
#
#     Volume XRP   Volume USDT
# 0    2384512.0  2.198450e+06
# 1  163438501.0  1.499400e+08
# 2  250074945.0  2.302303e+08
# 3  567234092.0  5.377035e+08
# 4  479436230.0  4.729372e+08

# %%
dataset.tail()
# Out:
#               unix        date    symbol     open     high      low    close  \
# 1329  1.530000e+12  05/08/2018  XRP-USDT  0.82490  0.84802  0.79200  0.80667
# 1330  1.530000e+12  05/07/2018  XRP-USDT  0.86482  0.86886  0.80000  0.82490
# 1331  1.530000e+12  05/06/2018  XRP-USDT  0.90280  0.91800  0.83774  0.86483
# 1332  1.530000e+12  05/05/2018  XRP-USDT  0.88980  0.93500  0.88800  0.90280
# 1333  1.530000e+12  05/04/2018  XRP-USDT  0.50000  1.50000  0.50000  0.88990
#
#        Volume XRP  Volume USDT
# 1329  12971303.18  10571844.13
# 1330  17303486.40  14192279.73
# 1331  16002035.80  13997141.56
# 1332  16816165.30  15282000.08
# 1333  20890213.82  18946724.69

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1334 entries, 0 to 1333
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unix         1334 non-null   float64
#  1   date         1334 non-null   object
#  2   symbol       1332 non-null   object
#  3   open         1334 non-null   float64
#  4   high         1334 non-null   float64
#  5   low          1334 non-null   float64
#  6   close        1334 non-null   float64
#  7   Volume XRP   1334 non-null   float64
#  8   Volume USDT  1334 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 93.9+ KB

# %%
dataset.isnull().sum()
# Out:
# unix           0
# date           0
# symbol         2
# open           0
# high           0
# low            0
# close          0
# Volume XRP     0
# Volume USDT    0
# dtype: int64

# %%
dataset.describe()
# Out:
#                unix         open         high          low        close  \
# count  1.334000e+03  1334.000000  1334.000000  1334.000000  1334.000000
# mean   1.583073e+12     0.473318     0.495597     0.450075     0.473632
# std    3.336806e+10     0.319903     0.341216     0.297513     0.320127
# min    1.530000e+12     0.135360     0.149380     0.101290     0.135490
# 25%    1.550000e+12     0.256295     0.263605     0.250050     0.256343
# 50%    1.580000e+12     0.326050     0.337595     0.315500     0.326050
# 75%    1.610000e+12     0.565155     0.599938     0.528917     0.566190
# max    1.640000e+12     1.833960     1.966890     1.652430     1.834680
#
#          Volume XRP   Volume USDT
# count  1.334000e+03  1.334000e+03
# mean   3.567016e+08  2.356279e+08
# std    5.914574e+08  4.840987e+08
# min    2.384512e+06  2.198450e+06
# 25%    6.448872e+07  1.894323e+07
# 50%    1.480822e+08  4.136179e+07
# 75%    3.779833e+08  2.519194e+08
# max    8.608358e+09  4.589984e+09

# %%
#Using Histograms for understanding Distributions
import matplotlib.pyplot as plt
import warnings
print("Imported Successfully")
warnings.filterwarnings("ignore")
for i in dataset.select_dtypes(include="number").columns:
    sb.histplot(data=dataset, x=i)
    plt.show()
# Out:
# Imported Successfully

# %%
#Scatter Plot to understand relationship (table)
dataset.select_dtypes(include="number")
# Out:
#               unix     open     high      low    close    Volume XRP  \
# 0     1.640000e+12  0.92000  0.92370  0.92000  0.92260  2.384512e+06
# 1     1.640000e+12  0.92520  0.93340  0.90520  0.92000  1.634385e+08
# 2     1.640000e+12  0.91140  0.93500  0.89810  0.92520  2.500749e+08
# 3     1.640000e+12  0.99410  0.99660  0.89640  0.91150  5.672341e+08
# 4     1.640000e+12  0.95380  1.01670  0.93720  0.99410  4.794362e+08
# ...            ...      ...      ...      ...      ...           ...
# 1329  1.530000e+12  0.82490  0.84802  0.79200  0.80667  1.297130e+07
# 1330  1.530000e+12  0.86482  0.86886  0.80000  0.82490  1.730349e+07
# 1331  1.530000e+12  0.90280  0.91800  0.83774  0.86483  1.600204e+07
# 1332  1.530000e+12  0.88980  0.93500  0.88800  0.90280  1.681617e+07
# 1333  1.530000e+12  0.50000  1.50000  0.50000  0.88990  2.089021e+07
#
#        Volume USDT
# 0     2.198450e+06
# 1     1.499400e+08
# 2     2.302303e+08
# 3     5.377035e+08
# 4     4.729372e+08
# ...

# %%
#Show any duplicates
dataset.drop_duplicates()
# Out:
#               unix        date    symbol     open     high      low    close  \
# 0     1.640000e+12  12-27-2021       NaN  0.92000  0.92370  0.92000  0.92260
# 1     1.640000e+12  12-26-2021  XRP-USDT  0.92520  0.93340  0.90520  0.92000
# 2     1.640000e+12  12-25-2021  XRP-USDT  0.91140  0.93500  0.89810  0.92520
# 3     1.640000e+12  12-24-2021       NaN  0.99410  0.99660  0.89640  0.91150
# 4     1.640000e+12  12-23-2021  XRP-USDT  0.95380  1.01670  0.93720  0.99410
# ...            ...         ...       ...      ...      ...      ...      ...
# 1329  1.530000e+12  05/08/2018  XRP-USDT  0.82490  0.84802  0.79200  0.80667
# 1330  1.530000e+12  05/07/2018  XRP-USDT  0.86482  0.86886  0.80000  0.82490
# 1331  1.530000e+12  05/06/2018  XRP-USDT  0.90280  0.91800  0.83774  0.86483
# 1332  1.530000e+12  05/05/2018  XRP-USDT  0.88980  0.93500  0.88800  0.90280
# 1333  1.530000e+12  05/04/2018  XRP-USDT  0.50000  1.50000  0.50000  0.88990
#
#         Volume XRP   Volume USDT
# ...

# %%
from sklearn.model_selection import train_test_split
print('Imported Successfully')
# Out:
# Imported Successfully

# %%
#Scatter Plot to understand relationship (columns)
dataset.select_dtypes(include="number").columns
# Out:
# Index(['unix', 'open', 'high', 'low', 'close', 'Volume XRP', 'Volume USDT'], dtype='object')
